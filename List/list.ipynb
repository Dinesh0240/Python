# %%
list = [10,12,12,'abc']
print(type(list))
# Out:
# <class 'list'>

# %%
list = []
print(type(list))
# Out:
# <class 'list'>

# %%
l = ['raj','shyam',1]
l.append(7)
print(l)
# Out:
# ['raj', 'shyam', 1, 7]

# %% [markdown]
# Extend function

# %%
l = ['raj','shyam',1]
l.extend('yash')
print(l)
# Out:
# ['raj', 'shyam', 1, 'y', 'a', 's', 'h']

# %% [markdown]
# Difference between append and extend

# %%
l = ['raj','shyam',1]
l.append(9)
print(l)
l.extend('yash')
print(l)
l.extend([100,'app'])
print(l)
l.extend([9])
print(l)
# Out:
# ['raj', 'shyam', 1, 9]
# ['raj', 'shyam', 1, 9, 'y', 'a', 's', 'h']
# ['raj', 'shyam', 1, 9, 'y', 'a', 's', 'h', 100, 'app']
# ['raj', 'shyam', 1, 9, 'y', 'a', 's', 'h', 100, 'app', 9]

# %%
l = [1,2,'hello','hey']# to reveerse the lsit 
l.reverse()
print(l)
# Out:
# ['hey', 'hello', 2, 1]

# %%
l = [1,2,'hello','hey']  #to insert element at a particular index use insert
l.insert(2,8)
print(l)
# Out:
# [1, 2, 8, 'hello', 'hey']

# %%
l = [1,2,6,2,8,1] # to arrange the integer values in teh ascending order
l.sort()
print(l)
# Out:
# [1, 1, 2, 2, 6, 8]

# %%
l = [1,2,'hello','hey',2,3,2,'hey'] # to count occurrence of a particular element
c = l.count('hey')
print("count:",c)
# Out:
# count: 2
