# %%
[x for x in [1,2,3,4] if x%3!=0]
# Out:
# [1, 2, 4]

# %%
a = [x+y for x in [1,2,3] for y in [1,2,3]]
print(a)
# Out:
# [2, 3, 4, 3, 4, 5, 4, 5, 6]

# %%
[x for x in range(1,5)]
# Out:
# [1, 2, 3, 4]
