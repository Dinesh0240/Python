# %%
n = 450
i= 1 
while(i<=5):
    # print("i:",i,end=' ')
    if (n%7==0 and n%9==0):
        print("num:",n)
        i+=1
    n-=1
    # print("n:",n)
# Out:
# num: 441
# num: 378
# num: 315
# num: 252
# num: 189

# %%
num = int(input("enter number:"))
print("Number:",num)
start = 2
count = True

while(start<num):
    if(num%start==0):
        count = False
        print(count)
        break
    start+=1
if(count==True):
    print(num,"is a Prime number")
else:
    print(num," is not a Prime number")
# Out:
# Number: 5
# 5 is a Prime number
