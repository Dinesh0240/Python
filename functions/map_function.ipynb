# %% [markdown]
# Map function -
#
# -> a higher order function which applies the  logic to each element of the  iterable
# -> syntax -
#         map( function_name, iterable)

# %% [markdown]
# Map vs for loop

# %%
l = ['1','3','3','4']
s = map

# %%
l = ["hey","hello"]

for i in l:
    print(len(i))   #instead of this we use map
# Out:
# 3
# 5

# %%
l = ["hey","hello"]

out=map(len, l)
print("out:",out)
print(next(out))
print(next(out))

out=list(map(len,l))
print("out::",out)
# Out:
# out: <map object at 0x0000011FFDDAEE60>
# 3
# 5
# out:: [3, 5]

# %% [markdown]
# ->create a list
# ->create a function which takes parameter name as n and it will return n*10
# ->it gives error

# %%
l = [1,2,3,4,5]

def fun(n):
    return (n*10)       #noraml function ke sath

out=map(fun,l)
print("out:",out)
print(next(out))
print(next(out))
print(next(out))
print(next(out))
print(next(out))
print(next(out))
# Out:
# out: <map object at 0x000001CAE9723910>
# 10
# 20
# 30
# 40
# 50
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[21], line 13
#      11 print(next(out))
#      12 print(next(out))
# ---> 13 print(next(out))
#
# StopIteration:

# %%
l = [1,2,3,4,5]

def fun(n):     #through normal function 
    return (n*10)

out=map(fun,l)
print("out:",out)
for i in out:
    print(i)
# Out:
# out: <map object at 0x000001CAE93A5750>
# 10
# 20
# 30
# 40
# 50

# %%
l = [1,2,3,4,5]     
# def fun(n):
#     return (n*10)

out=map(lambda n:n*10,l)        #using lambda

print("out:",out)
for i in out:
    print(i)
# Out:
# out: <map object at 0x000001CAEA22DAB0>
# 10
# 20
# 30
# 40
# 50

# %%
l = [1,2,3,4,5]     
# def fun(n):
#     return (n*10)

out=map(lambda n:n*10,l)        #using lambda

print("out:",out)
print(next(out))
print(next(out))
print(next(out))
print(next(out))
print(next(out))
# print(next(out))
# Out:
# out: <map object at 0x000001CAEA265450>
# 10
# 20
# 30
# 40
# 50

# %%
def fun(n):
    return n%2==0
    
l = [1,2,3,4,5]
a = map(fun,l)
print(list(a))
# print(a)
# print(next(a))
# print(next(a))
# print(next(a))
# Out:
# [False, True, False, True, False]

# %%
def fun(n):
    return n%2==0
    
l = [1,2,3,4,5]
a = filter(lambda b: b%2==0,l)
# print(list(a))
print(a)
print(next(a))
print(next(a))
# print(next(a))
# Out:
# ...
# 2
# 4

# %%
def fun(n):
    return n%2==0
    
l = [1,2,3,4,5]             #this does not gives values due to operator we use and return that boolean value after the operation 
a = map(lambda b: b%2==0,l)
# print(list(a))
print(a)
print(next(a))
print(next(a))
# print(next(a))
# Out:
# ...
# False
# True

# %%
def fun(n):
    return n%2==0
    
l = [1,2,3,4,5]
a = map(lambda b: b%2,l)  # this gives values due to operator we use and return taht value
# print(list(a))
print(a)
print(next(a))
print(next(a))
# print(next(a))
# Out:
# ...
# 1
# 0
