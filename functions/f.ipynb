# %% [markdown]
# Functions

# %% [markdown]
# a block of code or collection of statements which can be used again and again(reusable)

# %%
# #syntax - 
# def test(): #creating a function
#     a= 3
#     b = 4
#     print(a+b)
# test()  # to run a function 
# print("dinesh")
# test()
# Out:
# 7
# dinesh
# 7

# %% [markdown]
# global variable

# %%
# x = 3
# def test(): #when variable is created outside the function means it is a globel variable it can be used inside and outside the function
#     a= 3
#     b = 4
#     print(a+b)
#     print(x)
# test()
# Out:
# 7
# 3

# %% [markdown]
# local variable or local scope

# %%
# def test(): #when variable is created inside the function means it is a local variable it can not  be used outside but can be used inside 
#     a= 3
#     b = 4
#     y = 3
#     print(a+b)
#     # print(x)
# test()
# print("y:",y)
# Out:
# 7
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 8
#       6     # print(x)
#       7 test()
# ----> 8 print("y:",y)
#
# NameError: name 'y' is not defined

# %% [markdown]
# when the arguments are given

# %%
# #syntax - 
# def test(a,b):
#     # a= 3
#     # b = 4
#     print(a+b)
# test(35,4)
# print("dinesh")
# test(2,1)

# %% [markdown]
# prime number

# %%
# n = 9
# def p():
#     count = 0
#     for i in range(2,n):
#         if n%i==0:
#             count=1
#             break
#     if count==0:
#         print("prime",n)
#     else:
#         print("not prime",n)

# p()
# Out:
# not prime 9

# %% [markdown]
# how to take parameter  to a function

# %%
#passing teh parameter or argument to the function

def test(y):    # y is a parameter 
    print("value::",y) 
test(23)    #y is a argument here not parameter
# Out:
# value:: 23

# %% [markdown]
# factorial

# %%
# def fact(a):
#     prod = 1
#     while a>=1:
#         prod = prod*a
#         a-=1
#     print(prod)
# fact(4)
# Out:
# 24

# %%
def fact(a):
    prod = 1
    for i in range()

# %%
b=15
def val(b):
    print(b) 
        #here it is local varible
    b=30    #change or updated inside the function
    print(b)
val(b)
print(b)
# Out:
# 15
# 30
# 15
