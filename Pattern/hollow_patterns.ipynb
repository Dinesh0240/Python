# %%
r = int(input("enter no. of rows"))
for i  in range(r):
    for j in range(r):
        if j==0 or i==0 or j==r-i-1:
            print("*",end=" ")
        else:
            print(" ",end=" ")
    print()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 r = int(input("enter no. of rows"))
#       2 for i  in range(r):
#       3     for j in range(r):
#
# ValueError: invalid literal for int() with base 10: ''

# %%
r = 5 
for i in range(r):
    for j in range(r):
        if i==0 or i==j or j==r-1 :
            print("*",end=" ")
        else:
            print(" ",end=' ')
    print()
# Out:
# * * * * *
#   *     *
#     *   *
#       * *
#         *

# %%
r = 5
ch =65
for i in range(r): 
    for j in range(r):
        if i==r-1:
            print(chr(ch),end=' ')
            ch+=1
        else:
            print("-",end=" ")
    print()
# Out:
# - - - - -
# - - - - -
# - - - - -
# - - - - -
# A B C D E

# %%
r = 5
ch =65
for i in range(r): 
    for j in range(r):
        if j==r-i-1:
            ch = 65
            print(chr(ch),end=" ")
        elif  i==r-1 or j==r-1:
            ch+=1
            print(chr(ch),end=" ")
        else:
            print("-",end=" ")
    print()
# Out:
# - - - - A
# - - - A B
# - - A - B
# - A - - B
# A B C D E

# %%
r = 5
ch =65
for i in range(r): 
    for j in range(r):
        if j==r-i-1:
            print(chr(ch),end=" ")
        else:
            print("-",end=" ")
    print()
# Out:
# - - - - A
# - - - A -
# - - A - -
# - A - - -
# A - - - -
