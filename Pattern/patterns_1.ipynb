# %%
r = 4
for i in range(r):
    for j in range(2*r-1):
        if j>=r-i-1 and j<=r+i-1:
            print("*",end=" ")
        else:
            print("-",end=" ")
    print()
# Out:
# - - - * - - -
# - - * * * - -
# - * * * * * -
# * * * * * * *

# %%
r = 7
for i in range(r):
    for j in range(r//2+1):
        if j<r//2-i or (i>r//2 and j<i-r//2):
            print("-",end=" ")
        else:
            print("*",end=" ")
    print()
# Out:
# - - - *
# - - * *
# - * * *
# * * * *
# - * * *
# - - * *
# - - - *

# %%
r = 7
for i in range(r):
    for j in range(r//2+1):
        if j<=i or (i>r//2 and j<r-i):
            print("*",end=" ")
        else:
            print("-",end=" ")
    print()
# Out:
# * - - -
# * * - -
# * * * -
# * * * *
# * * * *
# * * * *
# * * * *

# %%
r = 4
for i in range(r):
    for j in range(2*r-1):
        if j<r-i-1 :
            print("-",end=" ")
        else:
            print("*",end=" ")
    print()
# Out:
# - - - * * * *
# - - * * * * *
# - * * * * * *
# * * * * * * *

# %%
r =5
n = 1
count = 0

for i in range(r):
    for j in range(2*r-1):
        if  j==r+i-1:
            print(n,end=" ")
            n+=1
        elif i==r-1 and j%2==0:
            count+=1
            print(count,end=" ")   
        else:
            if j==r-i-1:
                print("1",end=" ")
            else:
                print(" ",end=" ")
    print()
# Out:
#         1
#       1   2
#     1       3
#   1           4
# 1   2   3   4   5

# %%
r = 5
count= 1
n = 1
for i in range(r):
    for j in range(r):
        if i==0:
            print(n,end=" ")
            n+=1
        elif j==0:
            print(count,end=" ")
            count+=1
        else:
            if j==r-i-1:
                print("5",end=" ")
            else:
                print(" ",end=" ")
    print()
# Out:
# 1 2 3 4 5
# 1     5
# 2   5
# 3 5
# 4

# %%
r = 9
for i in range(r):
    for j in range(r):
        if j==r//2-i or j==r//2+i :
            print("*",end=" ")
        else:
            print("-",end=" ")
    print()
# Out:
# - - - - * - - - -
# - - - * - * - - -
# - - * - - - * - -
# - * - - - - - * -
# * - - - - - - - *
# - - - - - - - - -
# - - - - - - - - -
# - - - - - - - - -
# - - - - - - - - -

# %%
r = 5
n = 65
ch=65

for i in range(r):
    for j in range(r):
        if j==r-1:
            print(chr(n),end=" ")
            n+=1
        elif i==r-1:
            print(chr(ch),end=" ")
            ch+=1
        else:
            if j==r-i-1:
                print("A",end=" ")
            else:
                print("-",end=" ")
        
    print()
# Out:
# - - - - A
# - - - A B
# - - A - C
# - A - - D
# A B C D E

# %%
r = 5
ch =65
for i in range(r):
    for j in range(r):
        if i==r-1 or j==r-1 or j==r-i-1:
            print(chr(ch),end=" ")
            ch+=1
        else:
            print("-",end=" ")
        
    print()
# Out:
# - - - - A
# - - - B C
# - - D - E
# - F - - G
# H I J K L

# %%
r =4
for i in range(r):
    for j in range(r):
        if i==j:
            print("1",end=" ")
        
        else:
            print("-",end=" ")
    print()
# Out:
# 1 - - -
# - 1 - -
# - - 1 -
# - - - 1

# %%
r= 5
for i in range(r):
    for j in range(r):
        if (i==0 and  j%2==0) or (i==r//2 and j%2!=0) :
            print("*",end=" ")
        elif i==r-1 and j%2==0:
            print("*",end=" ")   
        else:
            print("",end=" ")
    print()
# Out:
# *  *  *
#
#  *  *
#
# *  *  *

# %%
r =5
for i in range(r):
    for j in range(r):
        if i==j or i==r-1 or i==0 or j==r//2 or j==r-i-1:
            print("*",end=" ")
        else:
            print(" ",end=" ")
    print()
# Out:
# * * * * *
#   * * *
#     *
#   * * *
# * * * * *

# %%
r = 4
for i in range(r):
    for j in range(r):
        if i==j or (i==r-1 and j%2!=0) or (i==r//2 and j%2==0):
            print("1",end=" ")
        else:
            if i==r-1 and j%2==0:
                print("0",end=" ")
            else:
                print("-",end=" ")
    print()
# Out:
# 1 - - -
# - 1 - -
# 1 - 1 -
# 0 1 0 1

# %%
r = 9
for i in range(r):
    for j in range(r//2+1):
        if j<r//2-i+1 or (i>r//2 and j<i-r//2+1):
            print("*",end=" ")
        else:
            print(" " \
            "",end=" ")
    print()
# Out:
# * * * * *
# * * * *
# * * *
# * *
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
r = 7
for i in range(r):
    for j in range(r):
        if j<r//2-i or (i>r//2 and j<i-r//2) or (j>r//2 and j>r//2+i) or () :
            print("-",end=" ")
        else:
            print("*",end=" ")
    print()
# Out:
# - - - * - - -
# - - * * * - -
# - * * * * * -
# * * * * * * *
# - * * * * * *
# - - * * * * *
# - - - * * * *

# %%
r = 4
for i in range(r):
    for j in range(2*r-1):
        if j<r-i-1:
            print("-",end=" ")
        else:
            print("*",end=" ")
    print()
# Out:
# - - - * * * *
# - - * * * * *
# - * * * * * *
# * * * * * * *

# %%
n = 4
for i in range(n):
    for j in range(i+1):
        if (i+j)%2==0:
            print("1",end=" ")
        else:
            print("0",end=" ")
    print()
# Out:
# 1
# 0 1
# 1 0 1
# 0 1 0 1

# %%
r = 3
for i in range(r):
    for j in range(r*3):
        if (i==r//2 and j%2!=0):
            print("*",end=" ")
        else:
            print("-",end=" ")
    print()
# Out:
# - - - - - - - - -
# - * - * - * - * -
# - - - - - - - - -
