# %% [markdown]
# Q1

# %%
s = 'Hello World'
print(s[0])
print(s[1])
print(s[2])
print(s[3])
print(s[4])
# Out:
# H
# e
# l
# l
# o

# %% [markdown]
# Q2

# %%
s = input("enter a string:")

s[1:-1]
# Out:
# 'ello worl'

# %% [markdown]
# Q3

# %%
s = 'PythonProgramming'
print(s[0:6])
print(s[6:17])
# Out:
# Python
# Programming

# %% [markdown]
# Q4

# %%
s = 'apple'     #
print(s[::-1])  #in order to reverse the string we need to give negative step
# Out:
# elppa

# %% [markdown]
# Q5

# %%
s = 'hello everyone'

s[0:14:2]
# Out:
# 'hloeeyn'

# %% [markdown]
# Q6

# %%
s = 'hello everyone'

s[1:14:2]
# Out:
# 'el vroe'

# %% [markdown]
# Q7

# %%
s = 'LearningPython'

s[-6:]
# Out:
# 'Python'

# %% [markdown]
# Q8

# %%
s = 'computer science'

print(s[0:8])
print(s[9:16])
# Out:
# computer
# science

# %% [markdown]
# Q9

# %%
s = 'DataScience'

s[4:11]
# Out:
# 'Science'

# %% [markdown]
# Q10

# %%
s = input("enter a string :")

n = int(input("entera num:"))

s[0:n]
# Out:
# 'he'

# %% [markdown]
# Q11

# %%
s = 'SlicingExamples'

s[0:15:2]
# Out:
# 'Siigxmls'

# %% [markdown]
# Q12

# %%
s = 'Elephant'

s[3:5]
# Out:
# 'ph'

# %% [markdown]
# Q13

# %%
s = 'abcdefghijklmnop'

s[6:11]
# Out:
# 'ghijk'

# %% [markdown]
# Q14

# %%
s = 'computer'

s[-4:]
# Out:
# 'uter'

# %% [markdown]
# Q15

# %%
s = 'OpenAIChatGPT'

print(s[0:7])   #slicing syntax -> string[start:end:step] here step gives direction as well as how much to move
print(s[4:10])
print(s[12::-1])  #reverse string print   
                  #print(s[::-1]) this is also correct where we do not need to specify start and end just give step to move in backward direction
# Out:
# OpenAIC
# AIChat
# TPGtahCIAnepO

# %% [markdown]
# Q16

# %%
s = 'OpenAIChatGPT'

s[2:11]
# Out:
# 'enAIChatG'

# %% [markdown]
# Q17

# %%
s = 'ABCDEFG'

s[0:7:2]
# Out:
# 'ACEG'

# %% [markdown]
# Q18

# %%
s = input("enter string:")
print(s)

reverse = s[::-1]
print(reverse)

if reverse==s:
    print("palendrome string")
else:
    print("not palendrome")
# Out:
# racecar
# racecar
# palendrome string

# %% [markdown]
# Q19

# %%
s = 'HelloPython'

s[3:7]
# Out:
# 'loPy'

# %% [markdown]
# Q20

# %%
s = input("enter a string:")
print(s[:]*2)
# Out:
# hellohello
