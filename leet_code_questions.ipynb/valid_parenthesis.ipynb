# %%
s = "()[]{}"
is_bracket = []

for i in range(0,len(s)):
    current = s[i]
    # print(i,current)

    if (current =="(" or current=="[" or current=="{"):
        is_bracket.append(s[i])

        print("is:",is_bracket)
    elif (current==")" and "("==is_bracket):
        print("valid",is_bracket,current)
        # is_bracket.pop(s[i])
        print("valid",is_bracket,current)
    elif (current=="]" and "[]"==is_bracket):
        print("valid",is_bracket,current)
    elif (current=="}" and "{"==is_bracket):
        print("valid",is_bracket,current)
    else:
        print('invalid')
# Out:
# is: ['(']
# invalid
# is: ['(', '[']
# invalid
# is: ['(', '[', '{']
# invalid

# %%
s = "([)]"#correct code
new = []
a = True

for i in range(len(s)):
    current = s[i]
    # print(current)
    # print(i,s[i],new,current)
    if (current =="(" or current=="[" or current=="{"):
        # print("before:",new)
        new.append(s[i])
        # print("after:",new)
    elif (current==")" and "(" in new):
        # print(new)
        new.pop()
        # print(new)
    elif (current=="]" and "[" in new):
        # print(new)
        new.pop()
        # print(new)
    elif (current=="}" and "{" in new):
        # print(new)
        new.pop()
        # print(new)
    elif new==[]:
        a = False

if new==[] and a==True:
    print(" valid",new)
else:
    print("not valid",new)
# Out:
# not valid ['(']

# %%
s = "(])"
n = []
a = True

i=0
while i<len(s):
    # print(s[i])
    # print("at start n:",n)
    if s[i]=='(' or s[i]=='[' or s[i]=='{':
        n.append(s[i])
    else:
        if len(n)>0:
            if (s[i]==')' and '(' in n[-1]=='(') and len(n)>0:
                n.pop()
            elif (s[i]==']' and '[' in n[-1]=='['):
                n.pop()
            elif (s[i]=='}' and '{' in n[-1]=='{'):
                n.pop()
                # print("n after pop:",n)
            elif n==[]:
                a=False
            else:
                a=False
            # print(n)
        else:
            if (s[i]==']' or s[i]==')' or s[i]=='}'):
                a=False

    i+=1
if n==[] and a==True:
    print(True,n)
else:
    print(False,n)
# Out:
# False []
