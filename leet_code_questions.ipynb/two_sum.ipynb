# %%
num = [2,7,11,15]
target = 22
s = 0
e = 1
new = []

while (s<len(num)-1):
    # print(s,num[s],e,num[e])
    add = num[s]+num[e]
    # print("sum:",sum)
    if add==target:
        new.append(s)
        new.append(e)
    e+=1
    if e>=len(num):
        s+=1
        e = s+1
print(new)
# Out:
# [1, 3]
