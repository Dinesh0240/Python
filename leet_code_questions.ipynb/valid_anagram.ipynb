# %%
s = "car"
t = "cat"

dict ={}
comp = {}
# if len(s)==len(t):
#     print("same no. of characters")
for i in range(len(s)):
    # print(s[i])
    if i not in dict:
        dict[s[i]] = dict
    print(dict)
for j in range(len(t)):
    comp[t[j]] = 1
# Out:
# {'c': {...}}
# {'c': {...}, 'a': {...}}
# {'c': {...}, 'a': {...}, 'r': {...}}

# %%
s = "anagram"
t = "nagaram"

dict ={}
comp = {}

if len(s)!=len(t):
    print("not anagram")

for i in range(len(s)):
    curr = s[i]
    if curr not in dict:
        dict[curr] = 1
    else:
        dict[curr] = dict[curr]+1
print(dict)
for j in range(len(t)):
    a = t[j]
    if a not in comp:
        comp[a] = 1
    else:
        comp[a] = comp[a]+1
print(comp)
if dict==comp:
    print("True",s,t)
else:
    print("False")
# Out:
# {'a': 3, 'n': 1, 'g': 1, 'r': 1, 'm': 1}
# {'n': 1, 'a': 3, 'g': 1, 'r': 1, 'm': 1}
# True anagram nagaram
