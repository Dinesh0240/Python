# %%
s = "0P"
new = s.lower()
print(new)
new_string=""

for i in new:
    if 65<=ord(i)<=90 or 97<=ord(i)<=122:
        new_string=new_string+i
print(new_string)

to_check = ''
start = 0
end = len(new_string)-1

while start<len(new_string):
    print(start,end,"values:",new_string[start],new_string[end])
    if new_string[start]==new_string[end]:
        to_check = to_check+new_string[start]
    print("l:",to_check)
    start+=1
    end-=1
# print(to_check)
if to_check==new_string:
    print("It is palindrome")
else:
    print("Not a palindrome")
# Out:
# 0p
# p
# 0 0 values: p p
# l: p
# It is palindrome

# %%
s = "0P"
new = s.lower()

new_string=""

for i in new:
    if 65<=ord(i)<=90 or 97<=ord(i)<=122:
        new_string=new_string+i


to_check = ""
start = 0
end = len(new_string)-1

while start<len(new_string):
    if new_string[start]==new_string[end]:
        to_check = to_check+new_string[start]
    start+=1
    end-=1

if to_check==new_string:
    print("It is palindrome")
else:
    print("Not a palindrome")
# Out:
# It is palindrome

# %%
s = "0P"  #another way to solve
new = s.lower()

new_string=""
pattern = '[a-zA-Z0-9]'
for i in new:
    if pattern :
        new_string=new_string+i


to_check = ""
start = 0
end = len(new_string)-1

while start<len(new_string):
    if new_string[start]==new_string[end]:
        to_check = to_check+new_string[start]
    start+=1
    end-=1

if to_check==new_string:
    print("It is palindrome")
else:
    print("Not a palindrome")
# Out:
# Not a palindrome

# %%
s = "A man, a plan, a canal: Panama"
new = s.lower()

new_string=""

for i in new:
    if 65<=ord(i)<=90 or 97<=ord(i)<=122 or 48<=ord(i)<=57 or 33<=ord(i)<=47:
        new_string=new_string+i


to_check = ""
start = 0
end = len(new_string)-1

while start<len(new_string):
    if new_string[start]==new_string[end]:
        to_check = to_check+new_string[start]
    start+=1
    end-=1

if to_check==new_string:
    print("It is palindrome")
else:
    print("Not a palindrome")
# Out:
# Not a palindrome

# %%
s = "Marge, let's \"[went].\" I await {news} telegram."   #correct verion of code
new = s.lower()
# print(new)
new_string=""  # new string to store converted to lower case letters or non-alphanumeric values from original list

for i in new:
    if 65<=ord(i)<=90 or 97<=ord(i)<=122 or 48<=ord(i)<=57 :
        new_string=new_string+i
# print(new_string)

to_check = "" # created to compare the list to find it is palindrome or not 
start = 0
end = len(new_string)-1

while start<len(new_string):
    if new_string[start]==new_string[end]:
        to_check = to_check+new_string[start]
    start+=1
    end-=1

if to_check==new_string:
    print("It is palindrome")
else:
    print("Not a palindrome")
# Out:
# It is palindrome

# %%
ch = 65
print(chr(ch))
# Out:
# A

# %%
ch = 'a'
print(ord(ch))
# Out:
# 97

# %%
s = 'heLlo'

i = 0
while i<len(s):
    print(s[i])
    if s[i]>=ord()
    i+=1
# Out:
# h
# e
# L
# l
# o

# %%
# Out:
# 32
