# %% [markdown]
# CSV file

# %%
import csv 

with open ("file.csv","r") as csv_file:
    csv_reader  = csv.reader(csv_file)

    print(csv_reader)
    # print(next(csv_reader))
    # print(next(csv_reader))

    for i in csv_reader:
        print(i)
        # print(i[1])
# Out:
# <_csv.reader object at 0x000001EFA11AA8C0>
# ['dinesh', 'choudhary']
# ['hello', ' hey']

# %%
import csv 

with open ("file.csv","r") as csv_file:
    csv_reader  = csv.reader(csv_file)

    print(csv_reader)
    # print(next(csv_reader))
    # print(next(csv_reader))

    for i in csv_reader:
        print(i[0])
        # print(i[1])
# Out:
# <_csv.reader object at 0x000001EFA11AAFE0>
# dinesh
# hello

# %%
# create a funcation name as palendrome check
# which take a string as a parameter 
# and return True or False wheter the string is palendrome or not
