# %% [markdown]
# concatination of two strings

# %%
"code" + "harry"
# Out:
# 'codeharry'

# %%
a = "1"
b = "2"
print(a + b)
# Out:
# 12

# %%
c = int('5')
d = int('8')
print(c + d)
# Out:
# 13

# %%
a = 34
b = 80
print(a>b)
# Out:
# False

# %%
num = int(input("Enter the number:"))
square = num*num
print("square:",square)
# Out:
# square: 4

# %%
string = "harry"
s = string[:4]
print(s)
s = string[:]
print(s)
# Out:
# harr
# harry

# %%
slicing = "programming"
s = slicing[1:8:2]
print(s)
# Out:
# rgam

# %%
s = "programming"
print(len(s))
# Out:
# 11

# %%
list = ["hello", 7 , 8.2 , True]
print(list)
print(list[0])
list[0] = "hey"
print(list[0])
print(list)

list.append("call")
print(list)

list.insert(2,789456) #insertion of the integer at the 2 index using the insertion method in list 
print(list)
# Out:
# ['hello', 7, 8.2, True]
# hello
# hey
# ['hey', 7, 8.2, True]
# ['hey', 7, 8.2, True, 'call']
# ['hey', 7, 789456, 8.2, True, 'call']

# %%
tuple = ("hello", 7 , 8.2 , True)
print(tuple)
# Out:
# ('hello', 7, 8.2, True)

# %%
num = int(input("Enter the number:"))
#print(num)

if num%2==0:
    print(f"{num} is even")
else:
    print(f"{num} is odd")
# Out:
# 12 is even

# %%
num = int(input("Enter the number:"))

if num>0:
    print(f"{num} is Positive")
elif num<0:
    print(f"{num} is Negative")
else:
    print(f"{num} is Zero")
# Out:
# -5 is Negative

# %%
num1 = int(input("enter the first number:"))
print("Num1:",num1)

num2 = int(input("enter the second number:"))
print("Num2:",num2)

# %%
# Write a program to find the greatest of three numbers.
num1 = int(input("Enter the number1:"))
print(num1)
num2 = int(input("Enter the number2:"))
print(num2)
num3 = int(input("Enter the number3:"))
print(num3)

if num1>=num2 and num1>=num3:
    print(f"num={num1} is the greatest")
elif num2>=num1 and num2>=num3:
    print(f"num={num2} is the greatest")
else:
    print(f"num={num3} is the greatest")
# Out:
# 8
# 9
# 10
# num=10 is the greatest

# %%
# Write a program to check whether a year is a leap year.
year = int(input("Enter the year:"))
print(year)
if (year %4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(f"Year {year} is a leap year")
else:
    print(f"Year {year} is not a leap year")
# Out:
# 2012
# Year 2012 is a leap year

# %%
grade = int(input("Enter the grades: "))
print(grade)

if grade>=90 and grade<=100:
    print("Grade A")
elif grade>=75 and grade<=89:
    print("Grade B")
elif grade>=50 and grade<=74:
    print("Grade C")
elif grade<50 and grade>=0:
    print("Fail")
else:
    print("Incorrect grades")
# Out:
# -1
# Incorrect grades

# %%
# Write a program to check if a character is:
# Vowel
# Consonant

char = input("Enter the character:")
print(char)

if len(char) == 1 and char.isalpha():
    if char in 'aeiouAEIOU':
        print(f"{char} is a vowel")
    else:
        print(f"{char} is a consonant")
else:
    print("invalid input")
# Out:
# A
# A is a vowel

# %%
# Write a program to calculate electricity bill:
# First 100 units → $5 per unit
# Next 100 units → $8 per unit
# Above 200 units → $10 per unit

unit = int(input("Enter the unit:"))
print("Unit:",unit)

if unit <= 100:
    total_cost = unit * 5
elif unit <= 200:
    total_cost = 100 * 5 + (unit - 100)* 8
else:
    total_cost = 100 * 5 + 100 * 8 + (unit - 200) * 10

print(f"Total cost: ${total_cost}")
# Out:
# Unit: 400
# Total cost: $3300

# %%
# Write a program to check whether a number is:
# Divisible by both 3 and 5
# Only by 3
# Only by 5
# Not divisible by either

num = int(input("Enter the number:"))
print(f"num: {num} ")

if num % 3 and num % 5:
    if num % 3 == 0 :
        print(f"{num} is divisible by 3")
        if num % 5 == 0:
            print(f"num: {num} ")
else:
    print(f"{num} not divisible by either 3 or 5")
# Out:
# num: 15
# 15 not divisible by either 3 or 5

# %%
num = int(input("Enter the number:"))
print(f"num: {num} ")

if num % 3 == 0 and num % 5 == 0:
    print(f"{num} is divisible by 3 and 5")
elif num % 3 == 0 :
    print(f"{num} is divisible by only 3 ")
elif num % 5 == 0 :
    print(f"{num} is divisible by only 5 ")
else:
    print(f"{num} is not divisible by nor 3 nor 5")
# Out:
# num: 15
# 15 is divisible by 3 and 5

# %%
n = int(input("Enter the number:"))

if n<=1:
    print("nor prime nor composite")
else:
    if

# %%
n = int(input("Enter the number:"))
print(n)
count = 0

for i in range(len(str(n))):
    rem = n%10
    count+=1
    n=n//10
print(f"number of digits: {count}")
# Out:
# 456321
# number of digits: 6

# %%
n = int (input("Enter the number:"))
sum = 0
for i in range(len(str(n))):
    sum = sum + n%10
    n = n//10
print(f"sum of digits: {sum}")
# Out:
# sum of digits: 15

# %%
n = 456
print(n)

last_digit = n%10
for i in range(len(str(n))):
    first_digit = n%10
    n=n//10
print("First digit:",first_digit)
print(f"Last digit: {last_digit}")
sum = first_digit + last_digit
print(f"Sum of first and last digit: {sum}")
# Out:
# 456
# First digit: 4
# Last digit: 6
# Sum of first and last digit: 10

# %%
n = 1234
print(f"NUM: {n}")
reverse_num = 0

for i in range(len(str(n))):
    reverse_num = reverse_num * 10 + n%10
    print(reverse_num)
    n = n//10
print(f"Reverse of the number: {reverse_num}")
# Out:
# NUM: 1234
# 4
# 43
# 432
# 4321
# Reverse of the number: 4321

# %%
num = int(input("Enter the number:"))
print("Num:",num)
power = int(input("Enter the power:"))
print("power:",power)
prod = 1

for i in range(power):
    print("power:",i)
    prod = prod * num
    print("prod:",prod)
print("Prod:",prod)
# Out:
# Num: 4
# power: 2
# power: 0
# prod: 4
# power: 1
# prod: 16
# Prod: 16

# %%
n = int(input("enter num:"))
print(n)

if n%3==0 and n%5==0:
    print(f"{n} is divisible by both 3 and 5")
elif n%3==0:
    print(f"{n} is divisible by 3")
elif n%5==0:
    print(f"{n} is divisible by 5")
else:
    print(f"{n} is not divisible by either 3 or 5")
# Out:
# 4
# 4 is not divisible by either 3 or 5

# %%
n = 4

for i in range(1,11):
    prod = n*i
    print(f"{prod}",end=' ')
# Out:
# 4 8 12 16 20 24 28 32 36 40

# %%
s = "DoctorPhenomenal"
print(s[::2])
# Out:
# DcoPeoea

# %%
s = 'samst'
i =0 
j = len(s)-1
e = 0
while i<j:
    if s[i]==s[j]:
        e = 1
        break
    j-=1
if e ==1:
    print("duplicate")
else:
    print("not duplicate")
# Out:
# duplicate

# %%
s = 'assessment'
i = 0
j = len(s)-1
count = 0

while(i<j):
    if (s[i] == s[j]):
        print("char_i:",s[i],"index_i:",i,"char_j:",s[j],"index_j:",j)
        count += 1
    j-=1
    if (i == j):
        # print(f"before reset:, i:{i}, j:{j}")
        j = len(s)-1
        i+=1
        # print(f"after reset:, i:{i}, j:{j}")
print(f"count: {count}")
# Out:
# char_i: s index_i: 1 char_j: s index_j: 5
# char_i: s index_i: 1 char_j: s index_j: 4
# char_i: s index_i: 1 char_j: s index_j: 2
# char_i: s index_i: 2 char_j: s index_j: 5
# char_i: s index_i: 2 char_j: s index_j: 4
# char_i: e index_i: 3 char_j: e index_j: 7
# char_i: s index_i: 4 char_j: s index_j: 5
# count: 7

# %%
s = "sanskar"
i = 0
j = 1

while(i<j):
    if (s[i] == s[j]):
        print("char_i:",s[i],"index_i:",i,"char_j:",s[j],"index_j:",j)
    i+=1
    if (i == j):
        # print(f"before reset:, i:{i}, j:{j}")
        i = 0
        j+=1
        # print(f"after reset:, i:{i}, j:{j}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 5
#       2 i = 0
#       3 j = 1
# ----> 5 while(i<j):
#       6     if (s[i] == s[j]):
#       7         print("char_i:",s[i],"index_i:",i,"char_j:",s[j],"index_j:",j)
#
# KeyboardInterrupt:

# %%
s = "assessment"
curr = 0
next = 1
duplicate = ''

while(next<len(s)-1):
    print(s[curr],s[next])
    if s[curr] == s[next]:
        if(s[curr] not in duplicate):
            duplicate += s[curr]
        print("duplicate:",duplicate)
        # if(s[curr] in duplicate)>=3:
        #     print(f"{s[curr]} is duplicate")
    next+=1
# Out:
# a s
# a s
# a e
# a s
# a s
# a m
# a e
# a n
